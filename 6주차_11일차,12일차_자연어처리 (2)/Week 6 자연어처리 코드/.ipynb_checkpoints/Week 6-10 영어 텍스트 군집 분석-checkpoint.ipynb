# %% [markdown]
# # Week 6-10 영어 텍스트 군집 분석

# %%
# 데이터 읽기

import os
import pandas as pd

os.chdir('C:\jwkim\lecture\LG전자_22')
review_df=pd.read_csv("thinq_e_review_result.csv")

review_df
# Out:
#                      date  star   like  \
# 0      September 18, 2021     1   12.0
# 1      September 19, 2021     1    NaN
# 2      September 18, 2021     2    6.0
# 3      September 18, 2021     1    2.0
# 4       September 1, 2021     1  104.0
# ...                   ...   ...    ...
# 11275        June 6, 2019     5    NaN
# 11276    November 9, 2020     5    NaN
# 11277       July 17, 2020     5    NaN
# 11278  September 27, 2020     1    NaN
# 11279     January 1, 2021     1    NaN
#
#                                                  comment  \
# 0      This app no longer works. It has just updated ...
# 1      Everything worked fine until a week or so ago....
# 2      App doesn't work with wired TV connection. EDI...
# 3      I'm trying this again by have Alexa connection...
# 4      Just embarrassing. Absolutely, 100%, will not ...
# ...                                                  ...
# 11275                            Good app. useful so far
# 11276           Its been helpful. Hope it stays that way
# 11277  Worked like it should and gave me feedback tha...
# 11278                            error routed device.. .
# 11279               Not connected with washing machine 😞
#
#                                                comment_n
# 0      ['app', 'longer', 'work', 'updated', 'tell', '...
# 1      ['everything', 'worked', 'fine', 'week', 'ago'...
# 2      ['app', 'work', 'wired', 'tv', 'connection', '...
# 3      ['trying', 'alexa', 'connection', 'turn', 'lg'...
# 4      ['embarrassing', 'absolutely', 'connect', 'goo...
# ...                                                  ...
# 11275                   ['good', 'app', 'useful', 'far']
# 11276                 ['helpful', 'hope', 'stay', 'way']
# 11277  ['worked', 'like', 'gave', 'feedback', 'wanting']
# 11278                      ['error', 'routed', 'device']
# 11279                ['connected', 'washing', 'machine']
#
# [11280 rows x 5 columns]

# %%
review_df['comment_n_str']=review_df['comment_n'].apply(lambda x: " ".join(eval(x)))
review_df
# Out:
#                      date  star   like  \
# 0      September 18, 2021     1   12.0
# 1      September 19, 2021     1    NaN
# 2      September 18, 2021     2    6.0
# 3      September 18, 2021     1    2.0
# 4       September 1, 2021     1  104.0
# ...                   ...   ...    ...
# 11275        June 6, 2019     5    NaN
# 11276    November 9, 2020     5    NaN
# 11277       July 17, 2020     5    NaN
# 11278  September 27, 2020     1    NaN
# 11279     January 1, 2021     1    NaN
#
#                                                  comment  \
# 0      This app no longer works. It has just updated ...
# 1      Everything worked fine until a week or so ago....
# 2      App doesn't work with wired TV connection. EDI...
# 3      I'm trying this again by have Alexa connection...
# 4      Just embarrassing. Absolutely, 100%, will not ...
# ...                                                  ...
# 11275                            Good app. useful so far
# 11276           Its been helpful. Hope it stays that way
# 11277  Worked like it should and gave me feedback tha...
# 11278                            error routed device.. .
# 11279               Not connected with washing machine 😞
#
#                                                comment_n  \
# 0      ['app', 'longer', 'work', 'updated', 'tell', '...
# 1      ['everything', 'worked', 'fine', 'week', 'ago'...
# 2      ['app', 'work', 'wired', 'tv', 'connection', '...
# 3      ['trying', 'alexa', 'connection', 'turn', 'lg'...
# 4      ['embarrassing', 'absolutely', 'connect', 'goo...
# ...                                                  ...
# 11275                   ['good', 'app', 'useful', 'far']
# 11276                 ['helpful', 'hope', 'stay', 'way']
# 11277  ['worked', 'like', 'gave', 'feedback', 'wanting']
# 11278                      ['error', 'routed', 'device']
# 11279                ['connected', 'washing', 'machine']
#
#                                            comment_n_str
# 0      app longer work updated tell login incorrect t...
# 1      everything worked fine week ago connect oven a...
# 2      app work wired tv connection edit tried app tv...
# 3      trying alexa connection turn lg tv webos tv lg...
# 4      embarrassing absolutely connect google home de...
# ...                                                  ...
# 11275                                good app useful far
# 11276                              helpful hope stay way
# 11277                  worked like gave feedback wanting
# 11278                                error routed device
# 11279                          connected washing machine
#
# [11280 rows x 6 columns]

# %%
# TfidfVectorizer 사용한 DTM 생성
from sklearn.feature_extraction.text import TfidfVectorizer

tfidfv = TfidfVectorizer(stop_words='english',ngram_range=(1,2), min_df=0.01,max_df=0.95)
feature_vect=tfidfv.fit_transform(review_df['comment_n_str'])

# %%
feature_vect
# Out:
# <11280x227 sparse matrix of type '<class 'numpy.float64'>'
# 	with 79965 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans

# 10개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0 
km_cluster = KMeans(n_clusters=10, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
print(cluster_label)
print(cluster_centers)
# Out:
# [9 3 6 ... 2 2 2]
# [[1.97047621e-01 2.31248822e-02 2.47639119e-02 3.62573488e-03
#   4.43084913e-02 1.32904514e-02 2.31703201e-02 9.12585958e-03
#   6.10078280e-02 3.30369407e-02 3.96699373e-02 6.12128732e-01
#   3.73819313e-02 2.71250717e-02 2.19265091e-02 2.66057002e-02
#   1.86664906e-02 4.66768036e-02 2.11903232e-02 9.36342741e-02
#   5.55305523e-02 3.79485427e-02 1.50723352e-01 3.68586482e-02
#   2.40146424e-02 1.13382459e-02 3.73476195e-02 2.90952980e-02
#   2.94031288e-02]
#  [1.53118300e-01 1.16676788e-02 5.42025621e-02 1.72290426e-02
#   3.37809292e-02 5.76026223e-03 1.45015895e-02 9.35924050e-03
#   1.22881942e-02 8.82044397e-03 6.35425713e-03 4.39876205e-02
#   2.31210844e-02 2.89987194e-02 1.02019195e-01 3.27839021e-01
#   2.47770276e-01 3.56280638e-01 2.80646594e-02 7.83368582e-02
#   1.92253472e-02 2.38651200e-02 3.93394579e-02 2.62200027e-02
#   3.74879008e-02 8.62743852e-03 2.79007865e-02 2.99357844e-02
#   1.56385757e-02]
#  [1.08953442e-01 5.69922529e-03 5.03906668e-02 6.43162683e-02
#   8.03854278e-02 4.62222662e-03 4.44085874e-02 3.98767066e-03
#   3.71047749e-02 6.55399097e-02 4.61574112e-02 1.62301004e-02
#   5.11535296e-02 7.11524205e-02 2.83228952e-02 1.03680926e-02
#   2.09935989e-03 7.28256557e-03 3.49224530e-02 4.45555757e-02
#   4.21419579e-02 8.55344686e-02 5.43643031e-03 7.77470765e-02
#   1.05901435e-02 3.52676503e-01 2.42647794e-02 1.18741318e-02
#   7.92305205e-03 4.77736338e-02 1.68742799e-02 5.62993195e-02
#   3.04080667e-02 3.22911762e-02 2.24281550e-02 3.44443254e-02
#   7.91336732e-03 3.15696104e-02 2.90873200e-02 7.51020633e-02
#   2.47537957e-02 6.18898975e-02 9.27834820e-03 3.91737867e-02
#   3.43011043e-02 5.15766242e-01 4.95501522e-02 7.52416965e-02
#   1.83424415e-02]
#  [1.37535304e-01 5.01046613e-03 1.83808828e-02 1.15091617e-02
#   2.79953849e-02 1.25788775e-02 1.87639230e-02 6.17360602e-03
#   3.53565925e-02 1.00253896e-01 3.11900587e-02 5.89123993e-02
#   3.53535101e-02 2.56100166e-02 2.33473807e-02 2.13904588e-02
#   8.78087164e-03 4.01523761e-02 2.17829289e-02 3.06100755e-02
#   1.98211634e-02 5.85075018e-02 3.65523777e-02 4.49904160e-02
#   8.18073076e-03 4.81867355e-03 3.11520932e-02 6.77809299e-01
#   1.36103641e-02]]

# %%
cluster_centers.shape
# Out:
# (10, 227)

# %%
review_df['cluster_label'] = cluster_label
review_df.head()
# Out:
#                  date  star   like  \
# 0  September 18, 2021     1   12.0
# 1  September 19, 2021     1    NaN
# 2  September 18, 2021     2    6.0
# 3  September 18, 2021     1    2.0
# 4   September 1, 2021     1  104.0
#
#                                              comment  \
# 0  This app no longer works. It has just updated ...
# 1  Everything worked fine until a week or so ago....
# 2  App doesn't work with wired TV connection. EDI...
# 3  I'm trying this again by have Alexa connection...
# 4  Just embarrassing. Absolutely, 100%, will not ...
#
#                                            comment_n  \
# 0  ['app', 'longer', 'work', 'updated', 'tell', '...
# 1  ['everything', 'worked', 'fine', 'week', 'ago'...
# 2  ['app', 'work', 'wired', 'tv', 'connection', '...
# 3  ['trying', 'alexa', 'connection', 'turn', 'lg'...
# 4  ['embarrassing', 'absolutely', 'connect', 'goo...
#
#                                        comment_n_str  cluster_label
# 0  app longer work updated tell login incorrect t...              9
# 1  everything worked fine week ago connect oven a...              0
# 2  app work wired tv connection edit tried app tv...              1
# 3  trying alexa connection turn lg tv webos tv lg...              1
# 4  embarrassing absolutely connect google home de...              6

# %%
review_df[review_df['cluster_label']==0].sort_values(by='comment_n_str')
# Out:
#                      date  star  like  \
# 11241    October 28, 2018     1   NaN
# 4033   September 22, 2020     3   1.0
# 1380         May 31, 2021     3   1.0
# 1266        June 19, 2021     3   NaN
# 6218     November 1, 2020     4   NaN
# ...                   ...   ...   ...
# 10795         May 1, 2021     1   NaN
# 6394     October 24, 2020     5   NaN
# 10826         May 3, 2020     1   NaN
# 7818   September 10, 2020     1   NaN
# 1176       April 19, 2021     2   NaN
#
#                                                  comment  \
# 11241      Not at aal good even account cannot be opened
# 4033   Where has the ability to add users to a device...
# 1380   There is no ability to control "5 in 1" or "am...
# 1266   Doesn't have the ability to record what your w...
# 6218   Having the ability to use this app as my T.V. ...
# ...                                                  ...
# 10795  This is yet another bleep app that is watching...
# 6394   I have yet to have a bad experience with this ...
# 10826             Not yet good app not working properly.
# 7818   ZERO STARS. WASTE OF TIME. QR codes do Not sca...
# 1176   Русский перевод - просто ад. You need to impro...
#
#                                                comment_n  \
# 11241       ['aal', 'good', 'even', 'account', 'opened']
# 4033   ['ability', 'add', 'user', 'device', 'gone', '...
# 1380   ['ability', 'control', 'amp', 'control', 'feat...
# 1266   ['ability', 'record', 'watching', 'via', 'app'...
# 6218   ['ability', 'use', 'app', 'v', 'remote', 'usef...
# ...                                                  ...
# 10795  ['yet', 'another', 'bleep', 'app', 'watching',...
# 6394   ['yet', 'bad', 'experience', 'app', 'notificat...
# 10826      ['yet', 'good', 'app', 'working', 'properly']
# 7818   ['zero', 'star', 'waste', 'time', 'qr', 'code'...
# 1176   ['русский', 'перевод', 'просто', 'ад', 'need',...
#
#                                            comment_n_str  cluster_label
# 11241                       aal good even account opened              0
# 4033   ability add user device gone latest app update...              0
# 1380      ability control amp control feature split unit              0
# 1266   ability record watching via app surely pretty ...              0
# 6218   ability use app v remote useful thing ever som...              0
# ...                                                  ...            ...
# 10795  yet another bleep app watching sell informatio...              0
# 6394   yet bad experience app notification time help ...              0
# 10826                      yet good app working properly              0
# 7818         zero star waste time qr code scan trash app              0
# 1176   русский перевод просто ад need improve russian...              0
#
# [5119 rows x 7 columns]

# %%
review_df[review_df['cluster_label']==1].sort_values(by='comment_n_str')
# Out:
#                      date  star  like  \
# 8718    February 14, 2020     4   NaN
# 10070  September 26, 2020     1   NaN
# 2993     October 27, 2020     2   5.0
# 9157    December 18, 2020     5   NaN
# 9023       April 25, 2020     1   2.0
# ...                   ...   ...   ...
# 7345      August 12, 2020     1   NaN
# 4495     February 3, 2021     1   2.0
# 17     September 18, 2021     1   NaN
# 2054         May 29, 2021     1   NaN
# 5829         May 18, 2020     1   2.0
#
#                                                  comment  \
# 8718   I cannot able change the channels for tv.. But...
# 10070      Not able to connect my google nest with LG tv
# 2993   I am able to control my tv using my phone, tha...
# 9157   I am able to controll my LG TV with my device(s).
# 9023   We not able to play mobile contents in this ap...
# ...                                                  ...
# 7345   Yep rather useless and what happened to being ...
# 4495   Yet another app for smart devices. Why should ...
# 17     It's been more than 2 yrs without any sensed c...
# 2054   There is no Zero. Cannot connectmy phone. The ...
# 5829   There is ZERO reason for you to have access to...
#
#                                                comment_n  \
# 8718   ['able', 'change', 'channel', 'tv', 'volume', ...
# 10070  ['able', 'connect', 'google', 'nest', 'lg', 'tv']
# 2993   ['able', 'control', 'tv', 'using', 'phone', 'o...
# 9157          ['able', 'controll', 'lg', 'tv', 'device']
# 9023   ['able', 'play', 'mobile', 'content', 'app', '...
# ...                                                  ...
# 7345   ['yep', 'rather', 'useless', 'happened', 'able...
# 4495   ['yet', 'another', 'app', 'smart', 'device', '...
# 17     ['yr', 'without', 'sensed', 'change', 'app', '...
# 2054   ['zero', 'connectmy', 'phone', 'registration',...
# 5829   ['zero', 'reason', 'access', 'contact', 'want'...
#
#                                            comment_n_str  cluster_label
# 8718      able change channel tv volume mute etc working              1
# 10070                     able connect google nest lg tv              1
# 2993   able control tv using phone one good thing cas...              1
# 9157                          able controll lg tv device              1
# 9023   able play mobile content app lg tv plus better...              1
# ...                                                  ...            ...
# 7345   yep rather useless happened able enter text tv...              1
# 4495   yet another app smart device keep another app ...              1
# 17     yr without sensed change app allows turn tv ev...              1
# 2054   zero connectmy phone registration screen timea...              1
# 5829   zero reason access contact want use app remote...              1
#
# [1295 rows x 7 columns]

# %%
review_df[review_df['cluster_label']==9].sort_values(by='comment_n_str')
# Out:
#                      date  star  like  \
# 4136    December 22, 2020     3   NaN
# 9504        June 11, 2020     1   NaN
# 5018   September 23, 2020     1   2.0
# 4708     January 20, 2019     1   1.0
# 10800       June 12, 2019     5   NaN
# ...                   ...   ...   ...
# 10455    January 11, 2020     5   NaN
# 7011       March 21, 2021     5   NaN
# 3343       March 18, 2020     1   1.0
# 10546      April 29, 2021     5   NaN
# 9764     October 18, 2018     1   NaN
#
#                                                  comment  \
# 4136   Was able to get connected and it works well. N...
# 9504                 Not able to make it work with Alexa
# 5018   Absolute rubbish, doesn't detect the tv anymor...
# 4708   absolutely awful. I have a masters degree in I...
# 10800  Absolutely love my LG Washer!!! App works grea...
# ...                                                  ...
# 10455  Wow awesome application am very happy it works...
# 7011   Wow, love the app. Very useful and works well ...
# 3343   In all my years of dev work, I've never seen a...
# 10546  Not yet download this app😂but I know it will w...
# 9764                   yup doesnt work with New OLED tvs
#
#                                                comment_n  \
# 4136   ['able', 'get', 'connected', 'work', 'well', '...
# 9504                   ['able', 'make', 'work', 'alexa']
# 5018   ['absolute', 'rubbish', 'detect', 'tv', 'anymo...
# 4708   ['absolutely', 'awful', 'master', 'degree', 's...
# 10800  ['absolutely', 'love', 'lg', 'washer', 'app', ...
# ...                                                  ...
# 10455  ['wow', 'awesome', 'application', 'happy', 'wo...
# 7011   ['wow', 'love', 'app', 'useful', 'work', 'well...
# 3343   ['year', 'dev', 'work', 'never', 'seen', 'app'...
# 10546  ['yet', 'download', 'app', 'know', 'work', 'sm...
# 9764      ['yup', 'doesnt', 'work', 'new', 'oled', 'tv']
#
#                                            comment_n_str  cluster_label
# 4136   able get connected work well notification oven...              9
# 9504                                able make work alexa              9
# 5018   absolute rubbish detect tv anymore work old ap...              9
# 4708   absolutely awful master degree spent hour phon...              9
# 10800           absolutely love lg washer app work great              9
# ...                                                  ...            ...
# 10455                 wow awesome application happy work              9
# 7011   wow love app useful work well appliance great ...              9
# 3343   year dev work never seen app work rooted devic...              9
# 10546  yet download app know work smoothly without clash              9
# 9764                         yup doesnt work new oled tv              9
#
# [863 rows x 7 columns]

# %%
# 군집별 핵심 단어 추출하기
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape :',cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape :
_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['app', 'lg', 'good', 'update', 'time', 'great', 'use', 'working', 'appliance', 'review']
# ========================================================================================================================
# ####### Cluster 1
# Top features: ['tv', 'lg', 'app', 'lg tv', 'remote', 'tv remote', 'turn', 'use', 'phone', 'plus']
# ========================================================================================================================
# ####### Cluster 2
# Top features: ['easy', 'easy use', 'use', 'app', 'helpful', 'great', 'good', 'useful', 'setup', 'set']
# ========================================================================================================================
# ####### Cluster 3
# Top features: ['ac', 'app', 'wifi', 'unit', 'time', 'connect', 'lg', 'control', 'option', 'temperature']
# ========================================================================================================================
# ####### Cluster 4
# Top features: ['rooted', 'rooted device', 'device', 'run rooted', 'run', 'phone', 'app', 'work', 'say', 'reason']
# ========================================================================================================================
# ####### Cluster 5
# Top features: ['permission', 'location', 'need', 'phone', 'access', 'app', 'make', 'requires', 'want', 'use']
# ========================================================================================================================
# ####### Cluster 6
# Top features: ['connect', 'tv', 'connect tv', 'app', 'wifi', 'lg', 'time', 'google', 'home', 'google home']
# ========================================================================================================================
# ####### Cluster 7
# Top features: ['washer', 'dryer', 'washer dryer', 'app', 'cycle', 'review', 'start', 'notification', 'lg', 'work']
# ========================================================================================================================
# ####### Cluster 8
# Top features: ['machine', 'washing', 'washing machine', 'app', 'cycle', 'lg', 'review', 'program', 'use', 'time']
# ========================================================================================================================
# ####### Cluster 9
# Top features: ['work', 'app work', 'app', 'great', 'work great', 'time', 'lg', 'tv', 'update', 'fine']
# ========================================================================================================================

# %%
review_df
# Out:
#                      date  star   like  \
# 0      September 18, 2021     1   12.0
# 1      September 19, 2021     1    NaN
# 2      September 18, 2021     2    6.0
# 3      September 18, 2021     1    2.0
# 4       September 1, 2021     1  104.0
# ...                   ...   ...    ...
# 11275        June 6, 2019     5    NaN
# 11276    November 9, 2020     5    NaN
# 11277       July 17, 2020     5    NaN
# 11278  September 27, 2020     1    NaN
# 11279     January 1, 2021     1    NaN
#
#                                                  comment  \
# 0      This app no longer works. It has just updated ...
# 1      Everything worked fine until a week or so ago....
# 2      App doesn't work with wired TV connection. EDI...
# 3      I'm trying this again by have Alexa connection...
# 4      Just embarrassing. Absolutely, 100%, will not ...
# ...                                                  ...
# 11275                            Good app. useful so far
# 11276           Its been helpful. Hope it stays that way
# 11277  Worked like it should and gave me feedback tha...
# 11278                            error routed device.. .
# 11279               Not connected with washing machine 😞
#
#                                                comment_n  \
# 0      ['app', 'longer', 'work', 'updated', 'tell', '...
# 1      ['everything', 'worked', 'fine', 'week', 'ago'...
# 2      ['app', 'work', 'wired', 'tv', 'connection', '...
# 3      ['trying', 'alexa', 'connection', 'turn', 'lg'...
# 4      ['embarrassing', 'absolutely', 'connect', 'goo...
# ...                                                  ...
# 11275                   ['good', 'app', 'useful', 'far']
# 11276                 ['helpful', 'hope', 'stay', 'way']
# 11277  ['worked', 'like', 'gave', 'feedback', 'wanting']
# 11278                      ['error', 'routed', 'device']
# 11279                ['connected', 'washing', 'machine']
#
#                                            comment_n_str  cluster_label
# 0      app longer work updated tell login incorrect t...              9
# 1      everything worked fine week ago connect oven a...              0
# 2      app work wired tv connection edit tried app tv...              1
# 3      trying alexa connection turn lg tv webos tv lg...              1
# 4      embarrassing absolutely connect google home de...              6
# ...                                                  ...            ...
# 11275                                good app useful far              0
# 11276                              helpful hope stay way              0
# 11277                  worked like gave feedback wanting              0
# 11278                                error routed device              0
# 11279                          connected washing machine              8
#
# [11280 rows x 7 columns]

# %%
# Dimension Reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=0)
pca_transformed = pca.fit_transform(feature_vect.toarray())
review_df['ftr1'] = pca_transformed[:,0]
review_df['ftr2'] = pca_transformed[:,1]

# %%
### Function to visualize clustering results  
import matplotlib.pyplot as plt
import numpy as np

def visualize_cluster_plot(clusterobj, dataframe, label_name, iscenter=True):
    if iscenter :
        centers = clusterobj.cluster_centers_
        
    unique_labels = np.unique(dataframe[label_name].values)
    markers=['o', 's', '^', 'x', '*','P','D','H','v','>','<','1','2','3','4']
    isNoise=False

    for label in unique_labels:
        label_cluster = dataframe[dataframe[label_name]==label]
        if label == -1:
            cluster_legend = 'Noise'
            isNoise=True
        else :
            cluster_legend = 'Cluster '+str(label)
        
        plt.scatter(x=label_cluster['ftr1'], y=label_cluster['ftr2'], s=70,\
                    edgecolor='k', marker=markers[label], label=cluster_legend)
        
        if iscenter:
            center_x_y = centers[label]
            plt.scatter(x=center_x_y[0], y=center_x_y[1], s=250, color='white',
                        alpha=0.9, edgecolor='k', marker=markers[0])  #label
            plt.scatter(x=center_x_y[0], y=center_x_y[1], s=70, color='k',\
                        edgecolor='k', marker='$%d$' % label)
    if isNoise:
        legend_loc='upper right'
    else: legend_loc='upper right'
    
    plt.legend(loc=legend_loc)
    plt.show()

# %%
visualize_cluster_plot(km_cluster, review_df, 'cluster_label', iscenter=False)

# %%
#DBSCAN
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.85, min_samples=5, metric='euclidean')
dbscan_labels = dbscan.fit_predict(feature_vect)

# %%
review_df['dbscan_cluster'] = dbscan_labels

# %%
review_df['dbscan_cluster'].value_counts()
# Out:
#  0    7519
# -1    3644
#  1      93
#  3       8
#  2       6
#  5       6
#  4       4
# Name: dbscan_cluster, dtype: int64

# %%
visualize_cluster_plot(dbscan, review_df, 'dbscan_cluster', iscenter=False)

# %%
review_df[review_df['dbscan_cluster']==4].sort_values(by='comment_n_str')
# Out:
#                    date  star  like  \
# 1101    August 27, 2021     1   NaN
# 9406   January 26, 2019     1   3.0
# 5454   January 28, 2019     1   NaN
# 7950  December 26, 2019     4   NaN
#
#                                                 comment  \
# 1101     Cleaner but more intrusive. Location needed???
# 9406  Developers need to remove requirement for perm...
# 5454  just needed to add a program to my NFC washer ...
# 7950  Usefull and functional, but unnecessary permis...
#
#                                               comment_n  \
# 1101     ['cleaner', 'intrusive', 'location', 'needed']
# 9406  ['developer', 'need', 'remove', 'requirement',...
# 5454  ['needed', 'add', 'program', 'nfc', 'washer', ...
# 7950  ['usefull', 'functional', 'unnecessary', 'perm...
#
#                                           comment_n_str  cluster_label  \
# 1101                  cleaner intrusive location needed              5
# 9406  developer need remove requirement permission n...              5
# 5454  needed add program nfc washer wifi app needed ...              0
# 7950   usefull functional unnecessary permission needed              5
#
#           ftr1      ftr2  dbscan_cluster
# 1101 -0.059029 -0.097228               4
# 9406 -0.072184 -0.210142               4
# 5454 -0.079212 -0.042505               4
# 7950 -0.057495 -0.100697               4

# %%
dbscan = DBSCAN(eps=0.8, min_samples=5, metric='euclidean')
dbscan_labels = dbscan.fit_predict(feature_vect)

# %%
review_df['dbscan_cluster'] = dbscan_labels

# %%
review_df['dbscan_cluster'].value_counts()
# Out:
#  0     5775
# -1     5152
#  10      93
#  2       31
#  8       29
#  1       26
#  5       18
#  23      17
#  6       14
#  21      12
#  9       11
#  16      10
#  18       9
#  3        9
#  19       8
#  13       8
#  25       7
#  22       6
#  7        6
#  17       5
#  20       5
#  12       5
#  4        5
#  14       5
#  11       5
#  24       5
#  15       4
# Name: dbscan_cluster, dtype: int64
